# %% [markdown]
# # 07 Geospatial Mapping
# Interactive prospectivity maps for Antioquia.

# %%
from aureo_ml.data.synthetic_generator import AntioquiaGeochemicalGenerator
from aureo_ml.visualization.geospatial_maps import prospectivity_map

df = AntioquiaGeochemicalGenerator().generate(1500)
prospectivity_map(df.head(1000))

# %% [markdown]
# Expected output: folium map centered on Antioquia with high-potential red targets around simulated mineralized corridors.
